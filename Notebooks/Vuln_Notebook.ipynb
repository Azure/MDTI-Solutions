# %% [markdown]
# # **Microsoft Defender Threat Intelligence**
#
# ## Jupyter NoteBook Demo for GBBs to present MDTI Graph API
#
# ##### Microsoft Defender Threat Intelligence (MDTI) is a complete threat intelligence platform that enables security professionals to ingest, analyze and act upon trillions of signals collected from across the internet and processed by security experts and AI. MDTI allows users to uncover and understand the global threat landscape as it relates to their organization, including context around vulnerabilities, threat actors, and the threat infrastructure that might be used to attack them.
#
# ##### Microsoft processes over 65-trillion signals every day. The key to operationalizing threat intelligence is to make it not just applicable, but actionable. Combined with AI and the expertise of 8,500 dedicated security professionals, this wealth of external telemetry and signal data is wrangled into immediately actionable insights.
#
# #  What Data can you obtain using the MDTI Graph API:
# - Reputation Scoring. Dynamically calculated severity scoring for IP addresses, domains, and hosts based on real-world threats and observations.
# - Components
# - Trackers
# - Threat Intel Article
# - Intel Profiles
# - Vulnerability

# %% [markdown]
# _____________________________________________________________
# # Get a Token from Azure Active Directory

# %% [markdown]
# #### Get the Client Secret and set to an environment variable

# %%
import os

# Read the client secret from a text file
with open("client_secret.txt", "r") as f:
    client_secret = f.read().strip()

# Set the client secret as an environment variable
os.environ["CLIENT_SECRET"] = client_secret

# %% [markdown]
# #### Get the Token with this cell

# %%
from msal import ConfidentialClientApplication

# Azure AD application credentials
client_id = "30232d95-233d-403b-a7d6-4aef57439f72"
tenant_id = "4b2462a4-bbee-495a-a0e1-f23ae524cc9c"


# Create a ConfidentialClientApplication object
app = ConfidentialClientApplication(
    client_id=client_id,
    client_credential=client_secret,
    authority=f"https://login.microsoftonline.com/{tenant_id}",
)

# Get a token from Azure AD
result = None
scopes = ["https://graph.microsoft.com/.default"]
result = app.acquire_token_silent(scopes=scopes, account=None)

if not result:
    result = app.acquire_token_for_client(scopes=scopes)

# Get the access token
access_token = result["access_token"]

# Print the access token
print("Access Token:", access_token)
# Out:
# Access Token: eyJ0eXAiOiJKV1QiLCJub25jZSI6Im1XRGo5MmJzdlI4aGhFZjZabTNiempBcW5oaEVKcjBTS3BnMnlYc3h3cTgiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....HgYxnnt7mtM6I5Y0bMeXvJorBPG0GEDet_hAtm3x-bQTt_5PrBIhiFKfWpvC2fXj18uPUPoCa8vADFAFujA87OypHgR-twykV0fyig7UZwpfcaGwfqSDry6rlH5J9R9tEesnDIznba4DoKcPv16zGwX3VX4R7EniV58Mk3yRUC983B-xnPjbShCsxJC9oTdl1kc4qkAa-6Z_IHuU1SxqHp8P7w9VqTXMfLcut2fdXRJlqeTF7RSaTYBc23bdpdxZ6bCLq3_drScpEy3tOLV_kD9uW3fIruW49NMrmFX2eY32v488LXx4G4waVS6MmtGXHQc_mHHR1K1iMYKKhxxzGw

# %% [markdown]
# _____________________________________________________________
# # Start Calling Graph APIs with different parameters

# %%
# Prompt user to enter Domain name or IP Address to investigate
entity_ID = input("Enter the Domain or IP Address you want to investigate: ")

print("The Domain Name or IP Address to be investigated is: " + entity_ID)
# Out:
# The Domain Name or IP Address to be investigated is: 062fe.com

# %% [markdown]
# ### Calling Graph API for Host Information

# %%
import requests
import json

# Graph API base URL
graph_api_base_url = f"https://graph.microsoft.com/beta/security/threatIntelligence/hosts/{entity_ID}"

# Create headers with Authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Send GET request to Graph API endpoint
response = requests.get(graph_api_base_url, headers=headers)

# Check for HTTP errors
try:
    response.raise_for_status()
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
else:
    # Print response content as JSON
    print(json.dumps(json.loads(response.content), indent=4))
# Out:
# {
#     "@odata.context": "https://graph.microsoft.com/beta/$metadata#security/threatIntelligence/hosts/$entity",
#     "@odata.type": "#microsoft.graph.security.hostname",
#     "id": "062fe.com",
#     "firstSeenDateTime": "2013-11-30T04:26:32Z",
#     "lastSeenDateTime": "2023-02-22T09:06:07Z",
#     "registrar": "Guangdong JinWanBang Technology Investment Co., Ltd.",
#     "registrant": "N/A"
# }

# %% [markdown]
# ### Calling Graph API Reputation

# %%
import requests
import json

# Graph API base URL
graph_api_base_url = "https://graph.microsoft.com/beta/security/threatIntelligence/hosts/062fe.com/reputation"

# Create headers with Authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Send GET request to Graph API endpoint
response = requests.get(graph_api_base_url, headers=headers)

# Check for HTTP errors
try:
    response.raise_for_status()
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
else:
    # Print response content as JSON
    print(json.dumps(json.loads(response.content), indent=4))
# Out:
# {
#     "@odata.context": "https://graph.microsoft.com/beta/$metadata#security/threatIntelligence/hosts('062fe.com')/reputation/$entity",
#     "id": "MDYyZmUuY29t",
#     "score": 100,
#     "classification": "malicious",
#     "rules": [
#         {
#             "name": "MDTI Intel Article",
#             "description": "Threat Insights: DEV-1101 NakedPages adversary-in-the-middle phishing kit",
#             "severity": "high",
#             "relatedDetailsUrl": "https://ti.defender.microsoft.com/article/e0c5c210"
#         },
#         {
#             "name": "Microsoft Blocklist (WatchList)",
#             "description": "This indicator relates to an emerging threat actor DEV-0563",
#             "severity": "high",
#             "relatedDetailsUrl": null
#         },
#         {
#             "name": "Microsoft Blocklist (WatchList)",
#             "description": "Please read the linked article(s) for more information on this threat. [\"https://ti.defender.microsoft.com/article/e0c5c210\"]",
#             "severity": "high",
#             "relatedDetailsUrl": null
#         },
#         {
#             "name": "Name server",
#             "description": "Domain is using a name server that has been associated with suspicious behavior",
#             "severity": "medium",
#             "relatedDetailsUrl": null
#         }
#     ]
# }

# %% [markdown]
# ### Calling Graph API for Reputation - Return only Reputation Class, Score and Rules triggered

# %%
import requests
import json

# Graph API base URL
graph_api_base_url = "https://graph.microsoft.com/beta/security/threatIntelligence/hosts/062fe.com/reputation"

# Create headers with Authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Send GET request to Graph API endpoint
response = requests.get(graph_api_base_url, headers=headers)

# Check for HTTP errors
try:
    response.raise_for_status()
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
else:
    # Parse response content as JSON
    json_response = json.loads(response.content)
    
    # Check if the response contains the word "suspicious"
    is_suspicious = any("suspicious" in rule.get("classification", "") for rule in json_response.get("rules", []))
    
    # Print classification, score, and rules
    print(f"Classification: {json_response['classification']}")
    print(f"Score: {json_response['score']}")
    print("Rules:")
    for rule in json_response.get("rules", []):
        if is_suspicious:
            print(f"\x1b[41m\x1b[37mSUSPICIOUS SITE\x1b[0m: {rule.get('name', '')}")
        else:
            print(f"{rule.get('name', '')}")
# Out:
# Classification: malicious
# Score: 100
# Rules:
# MDTI Intel Article
# Microsoft Blocklist (WatchList)
# Microsoft Blocklist (WatchList)
# Name server

# %% [markdown]
# ### Calling Graph API Components

# %%
import requests
import json

# Graph API base URL
graph_api_base_url = "https://graph.microsoft.com/beta/security/threatIntelligence/hosts/062fe.com/components"

# Create headers with Authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Send GET request to Graph API endpoint
response = requests.get(graph_api_base_url, headers=headers)

# Check for HTTP errors
try:
    response.raise_for_status()
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
else:
    # Print response content as JSON
    print(json.dumps(json.loads(response.content), indent=4))
# Out:
# {
#     "@odata.context": "https://graph.microsoft.com/beta/$metadata#Collection(microsoft.graph.security.hostComponent)",
#     "value": [
#         {
#             "id": "RGlnaXRhbE9jZWFuJCQkJEhvc3RpbmcgUHJvdmlkZXIkJDA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2023-02-09T14:07:37.8Z",
#             "lastSeenDateTime": "2023-02-09T14:07:37.8Z",
#             "name": "DigitalOcean",
#             "version": "",
#             "category": "Hosting Provider",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "RmFjZWJvb2skJCQkVHJhY2tpbmcgUGl4ZWwkJDA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2020-06-23T09:06:32.797Z",
#             "lastSeenDateTime": "2020-06-23T09:06:38.148Z",
#             "name": "Facebook",
#             "version": "",
#             "category": "Tracking Pixel",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "R29vZ2xlIEFuYWx5dGljcyQkJCRUcmFja2luZyBQaXhlbCQkMDYyZmUuY29t",
#             "firstSeenDateTime": "2020-06-23T09:06:32.797Z",
#             "lastSeenDateTime": "2020-06-23T09:06:38.148Z",
#             "name": "Google Analytics",
#             "version": "",
#             "category": "Tracking Pixel",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "Q2xvdWRGbGFyZSQkJCRERE9TIFByb3RlY3Rpb24kJDA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2020-06-23T09:05:18.351Z",
#             "lastSeenDateTime": "2020-06-23T09:06:38.148Z",
#             "name": "CloudFlare",
#             "version": "",
#             "category": "DDOS Protection",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "Y29udGVudC5tcWw1LmNvbSQkJCRUcmFja2luZyBQaXhlbCQkMDYyZmUuY29t",
#             "firstSeenDateTime": "2020-06-23T09:06:32.797Z",
#             "lastSeenDateTime": "2020-06-23T09:06:38.148Z",
#             "name": "content.mql5.com",
#             "version": "",
#             "category": "Tracking Pixel",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "Q2xvdWRGbGFyZSQkJCRTZXJ2ZXIkJDA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2020-06-23T09:05:18.351Z",
#             "lastSeenDateTime": "2020-06-23T09:06:31.984Z",
#             "name": "CloudFlare",
#             "version": "",
#             "category": "Server",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "Q2xvdWRGbGFyZSQkJCRDRE4kJDA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2020-06-23T09:05:18.351Z",
#             "lastSeenDateTime": "2020-06-23T09:06:31.984Z",
#             "name": "CloudFlare",
#             "version": "",
#             "category": "CDN",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "UEhQJCQ1LjUuMTkkJEZyYW1ld29yayQkMDYyZmUuY29t",
#             "firstSeenDateTime": "2020-06-23T09:05:18.351Z",
#             "lastSeenDateTime": "2020-06-23T09:05:18.393Z",
#             "name": "PHP",
#             "version": "5.5.19",
#             "category": "Framework",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "QVNQLk5FVCQkJCRGcmFtZXdvcmskJHd3dy4wNjJmZS5jb20=",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:57:41.521Z",
#             "name": "ASP.NET",
#             "version": "",
#             "category": "Framework",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "TWljcm9zb2Z0LUlJUyQkOC41JCRTZXJ2ZXIkJHd3dy4wNjJmZS5jb20=",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:57:41.521Z",
#             "name": "Microsoft-IIS",
#             "version": "8.5",
#             "category": "Server",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "alF1ZXJ5JCQxLjExLjMkJEphdmFTY3JpcHQgTGlicmFyeSQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "name": "jQuery",
#             "version": "1.11.3",
#             "category": "JavaScript Library",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "Y256ei5tbXN0YXQuY29tJCQkJFRyYWNraW5nIFBpeGVsJCR3d3cuMDYyZmUuY29t",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "name": "cnzz.mmstat.com",
#             "version": "",
#             "category": "Tracking Pixel",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "cGNvb2tpZS5jbnp6LmNvbSQkJCRUcmFja2luZyBQaXhlbCQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "name": "pcookie.cnzz.com",
#             "version": "",
#             "category": "Tracking Pixel",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "aG0uYmFpZHUuY29tJCQkJFRyYWNraW5nIFBpeGVsJCR3d3cuMDYyZmUuY29t",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "name": "hm.baidu.com",
#             "version": "",
#             "category": "Tracking Pixel",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "R29vZ2xlIEFuYWx5dGljcyQkJCRUcmFja2luZyBQaXhlbCQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "name": "Google Analytics",
#             "version": "",
#             "category": "Tracking Pixel",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "R29vZ2xlIEFkcyAtIERvdWJsZUNsaWNrJCQkJEFkIEV4Y2hhbmdlJCR3d3cuMDYyZmUuY29t",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:55:10.768Z",
#             "name": "Google Ads - DoubleClick",
#             "version": "",
#             "category": "Ad Exchange",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "R29vZ2xlIEFuYWx5dGljcyQkJCRBbmFseXRpY3MgU2VydmljZSQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:55:10.768Z",
#             "name": "Google Analytics",
#             "version": "",
#             "category": "Analytics Service",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         }
#     ]
# }

# %% [markdown]
# ### Calling Graph API Cookies

# %%
import requests
import json

# Graph API base URL
graph_api_base_url = "https://graph.microsoft.com/beta/security/threatIntelligence/hosts/062fe.com/cookies"

# Create headers with Authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Send GET request to Graph API endpoint
response = requests.get(graph_api_base_url, headers=headers)

# Check for HTTP errors
try:
    response.raise_for_status()
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
else:
    # Print response content as JSON
    print(json.dumps(json.loads(response.content), indent=4))
# Out:
# {
#     "@odata.context": "https://graph.microsoft.com/beta/$metadata#Collection(microsoft.graph.security.hostCookie)",
#     "@odata.nextLink": "https://graph.microsoft.com/beta/security/threatIntelligence/hosts/062fe.com/cookies?$skip=25",
#     "value": [
#         {
#             "id": "Lm1xbDUuY29tJCRsYW5nJCQwNjJmZS5jb20=",
#             "firstSeenDateTime": "2020-06-23T09:06:32.797Z",
#             "lastSeenDateTime": "2020-06-23T09:06:38.148Z",
#             "domain": ".mql5.com",
#             "name": "lang",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "LjA2MmZlLmNvbSQkX19jZmR1aWQkJDA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2020-06-23T09:05:18.351Z",
#             "lastSeenDateTime": "2020-06-23T09:06:38.148Z",
#             "domain": ".062fe.com",
#             "name": "__cfduid",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "MDYyZmUuY29tJCRQSFBTRVNTSUQkJDA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2020-06-23T09:05:18.351Z",
#             "lastSeenDateTime": "2020-06-23T09:06:38.148Z",
#             "domain": "062fe.com",
#             "name": "PHPSESSID",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "Z2VnZG0uZmVwbTYyLmNvbSQkQVNQLk5FVF9TZXNzaW9uSWQkJDA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2020-06-23T09:06:32.797Z",
#             "lastSeenDateTime": "2020-06-23T09:06:38.148Z",
#             "domain": "gegdm.fepm62.com",
#             "name": "ASP.NET_SessionId",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "LmZlcG02Mi5jb20kJF9fY2ZkdWlkJCQwNjJmZS5jb20=",
#             "firstSeenDateTime": "2020-06-23T09:06:32.797Z",
#             "lastSeenDateTime": "2020-06-23T09:06:38.148Z",
#             "domain": ".fepm62.com",
#             "name": "__cfduid",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "Lm1xbDUuY29tJCR1bmlxJCQwNjJmZS5jb20=",
#             "firstSeenDateTime": "2020-06-23T09:06:32.797Z",
#             "lastSeenDateTime": "2020-06-23T09:06:38.148Z",
#             "domain": ".mql5.com",
#             "name": "uniq",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "Lm1xbDUuY29tJCR1dG1fc291cmNlJCQwNjJmZS5jb20=",
#             "firstSeenDateTime": "2020-06-23T09:06:32.797Z",
#             "lastSeenDateTime": "2020-06-23T09:06:38.148Z",
#             "domain": ".mql5.com",
#             "name": "utm_source",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "LmNuenouY29tJCRjbmEkJHd3dy4wNjJmZS5jb20=",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": ".cnzz.com",
#             "name": "cna",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "Y29tJCRwdF9zXzEwZDBlMGIzJCR3d3cuMDYyZmUuY29t",
#             "firstSeenDateTime": "2018-05-26T07:55:10.768Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "com",
#             "name": "pt_s_10d0e0b3",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "Lm1tc3RhdC5jb20kJGNuYSQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": ".mmstat.com",
#             "name": "cna",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "JCRwdF8xMGQwZTBiMyQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:55:10.768Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "",
#             "name": "pt_10d0e0b3",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "d3d3LjA2MmZlLmNvbSQkX2NuenpfQ1YkJHd3dy4wNjJmZS5jb20=",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "www.062fe.com",
#             "name": "_cnzz_CV",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "MDYyZmUuY29tJCRfZ2lkJCR3d3cuMDYyZmUuY29t",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "062fe.com",
#             "name": "_gid",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "MDYyZmUuY29tJCRwdF9zXzEwZDBlMGIzJCR3d3cuMDYyZmUuY29t",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "062fe.com",
#             "name": "pt_s_10d0e0b3",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "LmNuenoubW1zdGF0LmNvbSQkYXRwc2lkYSQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": ".cnzz.mmstat.com",
#             "name": "atpsida",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "Y29tJCRwdF8xMGQwZTBiMyQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:55:10.768Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "com",
#             "name": "pt_10d0e0b3",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "MDYyZmUuY29tJCRwdF8xMGQwZTBiMyQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "062fe.com",
#             "name": "pt_10d0e0b3",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "d3d3LjA2MmZlLmNvbSQkQ05aWkRBVEExMjYxNDk3ODI1JCR3d3cuMDYyZmUuY29t",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "www.062fe.com",
#             "name": "CNZZDATA1261497825",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "MDYyZmUuY29tJCRIbV9scHZ0XzZmNzUxMjQwOTY1NGEyYTBhMDc3YTM4NGZlNDQxMTI2JCR3d3cuMDYyZmUuY29t",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "062fe.com",
#             "name": "Hm_lpvt_6f7512409654a2a0a077a384fe441126",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "d3d3LjA2MmZlLmNvbSQkcHRfc18xMGQwZTBiMyQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:55:10.768Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "www.062fe.com",
#             "name": "pt_s_10d0e0b3",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "MDYyZmUuY29tJCRIbV9sdnRfNmY3NTEyNDA5NjU0YTJhMGEwNzdhMzg0ZmU0NDExMjYkJHd3dy4wNjJmZS5jb20=",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "062fe.com",
#             "name": "Hm_lvt_6f7512409654a2a0a077a384fe441126",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "d3d3LjA2MmZlLmNvbSQkcHRfMTBkMGUwYjMkJHd3dy4wNjJmZS5jb20=",
#             "firstSeenDateTime": "2018-05-26T07:55:10.768Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "www.062fe.com",
#             "name": "pt_10d0e0b3",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "JCRwdF9zXzEwZDBlMGIzJCR3d3cuMDYyZmUuY29t",
#             "firstSeenDateTime": "2018-05-26T07:55:10.768Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "",
#             "name": "pt_s_10d0e0b3",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "MDYyZmUuY29tJCRfZ2EkJHd3dy4wNjJmZS5jb20=",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "domain": "062fe.com",
#             "name": "_ga",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "YmIuZmUwNjIuY29tJCRBU1AuTkVUX1Nlc3Npb25JZCQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:55:10.768Z",
#             "lastSeenDateTime": "2018-05-26T07:55:10.768Z",
#             "domain": "bb.fe062.com",
#             "name": "ASP.NET_SessionId",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         }
#     ]
# }

# %% [markdown]
# ### Calling Graph API Trackers

# %%
import requests
import json

# Graph API base URL
graph_api_base_url = "https://graph.microsoft.com/beta/security/threatIntelligence/hosts/062fe.com/trackers?count=true"

# Create headers with Authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Send GET request to Graph API endpoint
response = requests.get(graph_api_base_url, headers=headers)

# Check for HTTP errors
try:
    response.raise_for_status()
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
else:
    # Print response content as JSON
    print(json.dumps(json.loads(response.content), indent=4))
# Out:
# {
#     "@odata.context": "https://graph.microsoft.com/beta/$metadata#Collection(microsoft.graph.security.hostTracker)",
#     "@odata.count": 5,
#     "value": [
#         {
#             "id": "dWEtNzY1NTg2MjUkJEdvb2dsZUFuYWx5dGljc0FjY291bnROdW1iZXIkJDA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2020-06-23T09:05:18.351Z",
#             "lastSeenDateTime": "2020-06-23T09:05:18.393Z",
#             "kind": "GoogleAnalyticsAccountNumber",
#             "value": "ua-76558625",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "dWEtNzY1NTg2MjUtMiQkR29vZ2xlQW5hbHl0aWNzVHJhY2tpbmdJZCQkMDYyZmUuY29t",
#             "firstSeenDateTime": "2020-06-23T09:05:18.351Z",
#             "lastSeenDateTime": "2020-06-23T09:05:18.393Z",
#             "kind": "GoogleAnalyticsTrackingId",
#             "value": "ua-76558625-2",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "MTA2MDY3MjM2NTUzMTc2JCRGYWNlYm9va1BpeGVsSWQkJDA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2020-06-23T09:05:18.351Z",
#             "lastSeenDateTime": "2020-06-23T09:05:18.393Z",
#             "kind": "FacebookPixelId",
#             "value": "106067236553176",
#             "host": {
#                 "id": "062fe.com"
#             }
#         },
#         {
#             "id": "dWEtNzY1NTg2MjUkJEdvb2dsZUFuYWx5dGljc0FjY291bnROdW1iZXIkJHd3dy4wNjJmZS5jb20=",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "kind": "GoogleAnalyticsAccountNumber",
#             "value": "ua-76558625",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         },
#         {
#             "id": "dWEtNzY1NTg2MjUtMSQkR29vZ2xlQW5hbHl0aWNzVHJhY2tpbmdJZCQkd3d3LjA2MmZlLmNvbQ==",
#             "firstSeenDateTime": "2018-05-26T07:53:30.354Z",
#             "lastSeenDateTime": "2018-05-26T07:56:29.86Z",
#             "kind": "GoogleAnalyticsTrackingId",
#             "value": "ua-76558625-1",
#             "host": {
#                 "id": "www.062fe.com"
#             }
#         }
#     ]
# }

# %% [markdown]
# _____________________________________________________________
# ### Calling Graph API to get Article

# %% [markdown]
# #### Enter the Article ID for the article you wish to query for

# %%
# Prompt user to enter article ID
articleId = input("Enter the article ID: ")

print(articleId)

# %% [markdown]
# #### Graph API Call for the Article Requested

# %%
import requests
import json

# Graph API base URL
graph_api_base_url = "https://graph.microsoft.com/beta/security/threatIntelligence/articles/fbbd8e0c"

# Create headers with Authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Send GET request to Graph API endpoint
response = requests.get(graph_api_base_url, headers=headers)

# Check for HTTP errors
try:
    response.raise_for_status()
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
else:
    # Print response content as JSON
    print(json.dumps(json.loads(response.content), indent=4))
# Out:
# {
#     "@odata.context": "https://graph.microsoft.com/beta/$metadata#security/threatIntelligence/articles/$entity",
#     "id": "fbbd8e0c",
#     "createdDateTime": "2023-03-22T19:58:18.003Z",
#     "lastUpdatedDateTime": "2023-04-06T19:00:02.147Z",
#     "title": "IRIDIUM Uses TOR Hidden Services on Targets for Persistence and Evasion",
#     "isFeatured": true,
#     "tags": [
#         "IRIDIUM",
#         "T1546.008 - Accessibility Features",
#         "T1569.002 - Service Execution",
#         "T1133 - External Remote Services",
#         "T1599 - Network Boundary Bridging",
#         "T1572 - Protocol Tunneling"
#     ],
#     "imageUrl": "https://cdn-riq-ti.azureedge.net/Map.jpg",
#     "summary": {
#         "content": "Microsoft has identified a post-compromise persistence mechanism attributed to IRIDIUM that involves installing TOR hidden services on target devices for persistent access and network boundary protection evasion. This activity is being tracked as\u00a0*ShadowLink.*\r\n\r\nUpon accessing the target device, the actor uses a software package masquerading as\u00a0*Microsoft Defender*\u00a0files that installs the TOR service on that device, giving that device a unique\u00a0*.onion*\u00a0address. This configuration provides malicious actors with covert access to the system through the TOR network. After establishing the target device on the TOR network, the attacker can bypass network protections that prevent external services from accessing resources within a firewall boundary, as TOR relies on outbound connections from the client and the server to connect.\r\n\r\nIdentified targets span 13 countries (Europe, North America, and South America), primarily in the telecommunications industry, specifically internet service providers, but also other industries, such as education, retail, motor vehicles, county government, and data services. The earliest observed activity was in September 2020, while the most recent was in early November 2022, as of the time of this report.\r\n\r\nMicrosoft Defender Antivirus detects and prevents this activity with the HackTool:Win64/ShadowLink.A!dha and HackTool:Win64/ShadowLink.B!dha detections.",
#         "format": "markdown"
#     },
#     "body": {
#         "content": "#### Targeted Geolocations\r\n- Belgium  \r\n- Brazil  \r\n- Chile  \r\n- Spain  \r\n- United Kingdom  \r\n- India  \r\n- Italy  \r\n- Mexico  \r\n- Poland  \r\n- Thailand  \r\n- T\u00fcrkiye  \r\n- Ukraine  \r\n- United States\r\n#### Targeted Industries\r\n- Information Technology  \r\n    - Internet Routing, Access & Connection  \r\n    - Internet-based Content, Information & Communication  \r\n- Government Agencies & Services  \r\n    - General Public Services - Local  \r\n- Consumer Retail  \r\n- Education\r\n## Snapshot\r\nMicrosoft has identified a post-compromise persistence mechanism attributed to IRIDIUM that involves installing TOR hidden services on target devices for persistent access and network boundary protection evasion. This activity is being tracked as\u00a0*ShadowLink.*\r\n\r\nUpon accessing the target device, the actor uses a software package masquerading as\u00a0*Microsoft Defender*\u00a0files that installs the TOR service on that device, giving that device a unique\u00a0*.onion*\u00a0address. This configuration provides malicious actors with covert access to the system through the TOR network. After establishing the target device on the TOR network, the attacker can bypass network protections that prevent external services from accessing resources within a firewall boundary, as TOR relies on outbound connections from the client and the server to connect.\r\n\r\nIdentified targets span 13 countries (Europe, North America, and South America), primarily in the telecommunications industry, specifically internet service providers, but also other industries, such as education, retail, motor vehicles, county government, and data services. The earliest observed activity was in September 2020, while the most recent was in early November 2022, as of the time of this report.\r\n\r\nMicrosoft Defender Antivirus detects and prevents this activity with the HackTool:Win64/ShadowLink.A!dha and HackTool:Win64/ShadowLink.B!dha detections.\r\n## Activity Overview\r\nMicrosoft identified a post-compromise persistence mechanism attributed to IRIDIUM that involves installing TOR hidden services on target devices. When TOR hidden services are installed on a device, the device becomes a TOR network server with a unique\u00a0*.onion*\u00a0domain that the attacker can connect to using the domain and a pre-configured port number, in this case port 3389, redirecting the attacker\u2019s malicious traffic to the device\u2019s Remote Desktop Protocol service on the local system.\r\n\r\n## Timeline\r\n\r\nThis behavior was identified as early as September 2020, continuing sporadically throughout the last few months of 2020, 2021, and 2022, with the latest example occurring in early November 2022, as of the time of this report.\r\n\r\n![](https://cdn-riq-ti.azureedge.net/iridium-timeline.png)\r\n\r\n*IRIDIUM TOR hidden service attack diagram*\r\n\r\n## Attack chain\r\n\r\nThis activity is referred to as\u00a0*ShadowLink*\u00a0which establishes persistence through TOR at a late stage of compromise. IRIDIUM is known to use a variety of means to compromise a target network.\r\n\r\n- Upon accessing the target network, several methods have been identified to create the TOR installation software package on a device. The TOR installation software package is included in a self-extracting RAR archive (SFX), often named\u00a0*defender.exe.*\u00a0These SFXs might be introduced to a target network in a variety of ways but have been historically retrieved through actor-controlled URLs from commodity file-sharing websites such as\u00a0*anonfiles.com*. Other instances of SFXs \u00a0indicate distribution following infections of DarkCrystal RAT\u2014a remote access tool often used by IRIDIUM.\r\n- Typically using PowerShell, the attacker installs a service on the device using the newly downloaded RAR archive. This sets up the TOR hidden service on the device and configures its parameters. The service is named Tor Win32 Service.\r\n-  ...
#         "format": "markdown"
#     }
# }

# %% [markdown]
# _____________________________________________________________
# ### Graph API call for Intel Profile

# %% [markdown]
# #### Get the Profile Id

# %%
# Prompt user to enter article ID
ProfileId = input("Enter the Profile ID: ")

print(ProfileId)

# %% [markdown]
# #### Graph API Call to return Intel Profile Requested

# %%
import requests
import json

# Graph API base URL
graph_api_base_url = "https://graph.microsoft.com/beta/security/threatIntelligence/intelProfiles/9b01de37bf66d1760954a16dc2b52fed2a7bd4e093dfc8a4905e108e4843da80"

# Create headers with Authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Send GET request to Graph API endpoint
response = requests.get(graph_api_base_url, headers=headers)

# Check for HTTP errors
try:
    response.raise_for_status()
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
else:
    # Print response content as JSON
    print(json.dumps(json.loads(response.content), indent=4))
# Out:
# {
#     "@odata.context": "https://graph.microsoft.com/beta/$metadata#security/threatIntelligence/intelProfiles/$entity",
#     "id": "9b01de37bf66d1760954a16dc2b52fed2a7bd4e093dfc8a4905e108e4843da80",
#     "kind": "actor",
#     "title": "ACTINIUM",
#     "firstActiveDateTime": "2020-02-24T11:13:16Z",
#     "aliases": [
#         "Primitive Bear",
#         "SectorC08",
#         "shuckworm",
#         "Gamaredon",
#         "UNC530",
#         "Armageddon"
#     ],
#     "targets": [
#         "Government Agencies & Services: Defense",
#         "Government Agencies & Services: Law Enforcement",
#         "Non-Government Organization: Human Rights Organization"
#     ],
#     "sponsorStates": [
#         {
#             "label": "Russia",
#             "code": "ru"
#         }
#     ],
#     "summary": {
#         "content": "The actor that Microsoft tracks as ACTINIUM is a nation-state activity group based out of Russia. The Ukrainian government has publicly attributed this group to the Russian Federal Security Service (FSB). ACTINIUM is known to primarily target organizations in Ukraine including government entities, military, non-governmental organizations, judiciary, law enforcement, and non-profit, as well as entities related to Ukrainian affairs. ACTINIUM focuses on espionage and exfiltration of sensitive information. ACTINIUM\u2019s tactics are constantly evolving and encompass a multitude of advanced techniques and procedures. The actor is known to primarily use spear-phishing emails with malicious attachments that contain a first-stage payload that downloads and launches further payloads. The actor uses a variety of custom tools and malware to achieve their objectives, often using heavily obfuscated VBScripts, obfuscated PowerShell commands, self-extracting archives, Windows shortcut (LNK) files, or a combination of these. ACTINIUM frequently relies on scheduled tasks in these scripts to maintain persistence. ACTINIUM\u2019s operational infrastructure consists of many domains and hosts to facilitate payload staging and command-and-control (C2) and the actor frequently modifies or alters their infrastructure to evade detection. ACTINIUM also deploys tools like Pterodo\u2014a constantly evolving malware family\u2014to gain interactive access to target networks, maintain persistence, and gather intelligence. In some cases, they also deploy UltraVNC \u2014a remote desktop software utility\u2014to enable a more interactive connection to a target. ACTINIUM employs a variety of malware families including DinoTrain, DesertDown, DilongTrash, ObfuBerry, ObfuMerry, and PowerPunch. ACTINIUM is tracked by other security companies as Gamaredon, Armageddon, Primitive Bear, and UNC530.",
#         "format": "markdown"
#     },
#     "description": {
#         "content": "## Snapshot\r\nThe actor that Microsoft tracks as ACTINIUM is a nation-state activity group based out of Russia. The Ukrainian government has publicly attributed this group to the Russian Federal Security Service (FSB). ACTINIUM is known to primarily target organizations in Ukraine including government entities, military, non-governmental organizations, judiciary, law enforcement, and non-profit, as well as entities related to Ukrainian affairs. ACTINIUM focuses on espionage and exfiltration of sensitive information. ACTINIUM\u2019s tactics are constantly evolving and encompass a multitude of advanced techniques and procedures. The actor is known to primarily use spear-phishing emails with malicious attachments that contain a first-stage payload that downloads and launches further payloads. The actor uses a variety of custom tools and malware to achieve their objectives, often using heavily obfuscated VBScripts, obfuscated PowerShell commands, self-extracting archives, Windows shortcut (LNK) files, or a combination of these. ACTINIUM frequently relies on scheduled tasks in these scripts to maintain persistence. ACTINIUM\u2019s operational infrastructure consists of many domains and hosts to facilitate payload staging and command-and-control (C2) and the actor frequently modifies or alters their infrastructure to evade detection. ACTINIUM also deploys tools like Pterodo\u2014a constantly evolving malware family\u2014to gain interactive access to target networks, maintain persistence, and gather intelligence. In some cases, they also deploy UltraVNC \u2014a remote desktop software utility\u2014to enable a more interactive connection to a target. ACTINIUM employs a variety of malware families including DinoTrain, DesertDown, DilongTrash, ObfuBerry, ObfuMerry, and PowerPunch. ACTINIUM is tracked by other security companies as Gamaredon, Armageddon, Primitive Bear, and UNC530.\r\n## Targeting Details\r\n[ACTINIUM](https://attack.mitre.org/groups/G0047/) primarily targets Ukrainian-based or affiliated organizations. The group has also previously targeted non-Ukrainian government entities likely involving intelligence requirements related to Ukraine.\r\n\r\nACTINIUM target verticals include:\r\n\r\n- Government organizations\r\n- Law enforcement/Judiciary\r\n- Military\n Humanitarian organizations\r\n\r\nMicrosoft security researchers assess that most ACTINIUM targets will be based in or have some affiliation with Ukraine.\r\n",
#         "format": "markdown"
#     },
#     "tradecraft": {
#         "content": "ACTINIUM primarily uses spear phishing emails to infect targets. These emails harness remote template injection to load malicious code or content. Typically, this content will involve a malicious macro that contains a VBScript which loads further capabilities, such as scripts or malware, to gain access to a target device. Delivery using remote template injection ensures that malicious content only loads when required, such as when the user opens the document. This tactic assists attackers in evading static detections from systems that scan attachments for malicious content. Hosting the macro remotely also allows an attacker to control when and how the malicious component is delivered, further evading detection by preventing automated systems from obtaining and analyzing the malicious component. ACTINIUM operators often attach a self-executing archive with SFX or RAR files containing obfuscated scripts to a spear phishing email. These scripts are coded to download further malicious payloads or drop and invoke remote access tools that allow ACTINIUM direct interaction with the target device.  Microsoft security researchers have observed the group use a range of email phishing lures, including those that impersonate and masquerade as legitimate organizations, with benign attachments to establish trust and familiarity with the target, as shown below.\r\n\r\n![](https://cdn-riq-ti.azureedge.net/90f89e36-a0f7-450b-a3cd-89694a80b991)  \r\n\r\nACTINIUM has inserted web bugs within the body of a phishing message. Web bugs are small external image references that enable the actor to track when a message has been opened and rendered. While not malicious themselves, web bugs might indicate that the email is intended for malicious use, as shown below.\r\n\r\n![](https://cdn-riq-ti.azureedge.net/b14001e1-b039-464b-bf66-27c227a2fc57)  \r\n\r\nACTINIUM\u2019s lure documents appear legitimate and vary in style and content. For example, the lure document shown below includes a remote template.\r\n\r\n![](https://cdn-riq-ti.azureedge.net/0722a670-fcd4-4433-af26-42e8e840829d)  \r\n\r\n![](https://cdn-riq-ti.azureedge.net/9bdf675a-574b-4ab8-808c-4f03b5a24e80)  \r\n\r\nACTINIUM phishing attachments contain a first-stage payload that downloads and executes further payloads, at which point multiple subsequent \u201cstaging\u201d scripts might follow before a more fully featured malicious capability deploys to a compromised device. While the reason behind the multiple stages remains unclear, one hypothesis is that these staging VBScripts are easier to modify to incorporate new obfuscation or command-and-control (C2) changes. ACTINIUM might deploy these scripts to help prevent detection systems from detecting its main capabilities. These initial staging capabilities vary, with examples including heavily obfuscated VBScripts, obfuscated PowerShell commands, self-extracting archives, *.Lnk* files, or a combination of these.\r\n\r\nACTINIUM most often relies on scheduled tasks in the group\u2019s scripts to maintain persistence. See the Malware section and Microsoft blog post for additional [details](https://www.microsoft.com/security/blog/2022/02/04/actinium-targets-ukrainian-organizations/).\r\n\r\n### ATT&CK techniques\r\n\r\n[ACTINIUM](https://attack.mitre.org/groups/G0047/) has exhibited use of the following attack techniques. For standard industry documentation about these techniques, refer to the [MITRE ATT&CK framework](https://attack.mitre.org/).\r\n\r\n- Use of spear phishing with a malicious macro containing a VBScript\r\n\r\n    - [T1566.001 Phishing: Spearphishing Attachment](https://attack.mitre.org/techniques/T1566/001/)\r\n    - [T1204.002 User Execution: Malicious File](https://attack.mitre.org/techniques/T1204/002/)\r\n    - [T1137.001 Office Application Startup: Office Template Macros](https://attack.mitre.org/techniques/T1137/001/)\r\n    - [T1221 Template Injection](https://attack.mitre.org/techniques/T1221/)\r\n   ...
#         "format": "markdown"
#     }
# }

# %% [markdown]
# _____________________________________________________________
# ### Graph API Query for Vulnerability

# %% [markdown]
# #### Get the Vulnerability to query for

# %%
# Prompt user to enter article ID
VulnId = input("Enter the article ID: ")

print("The Vulnerability to be investigated is: " + VulnId)
# Out:
# The Vulnerability to be investigated is: CVE-2023-0669

# %% [markdown]
# #### API Call to return the Vulnerability information for request

# %%
import requests
import json

# Graph API base URL
graph_api_base_url = "https://graph.microsoft.com/beta/security/threatIntelligence/vulnerabilities/CVE-2023-0669"

# Create headers with Authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Send GET request to Graph API endpoint
response = requests.get(graph_api_base_url, headers=headers)

# Check for HTTP errors
try:
    response.raise_for_status()
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
else:
    # Print response content as JSON
    print(json.dumps(json.loads(response.content), indent=4))
# Out:
# {
#     "@odata.context": "https://graph.microsoft.com/beta/$metadata#security/threatIntelligence/vulnerabilities/$entity",
#     "id": "CVE-2023-0669",
#     "createdDateTime": "2023-02-04T00:41:50.186Z",
#     "lastModifiedDateTime": "2023-04-10T20:15:00Z",
#     "publishedDateTime": "2023-02-06T20:15:00Z",
#     "priorityScore": 86,
#     "severity": "high",
#     "commonWeaknessEnumerationIds": [
#         "CWE-502"
#     ],
#     "hasChatter": true,
#     "exploitsAvailable": true,
#     "activeExploitsObserved": false,
#     "description": {
#         "content": "Fortra (formerly, HelpSystems) GoAnywhere MFT suffers from a pre-authentication command injection vulnerability in the License Response Servlet due to deserializing an arbitrary attacker-controlled object. This issue was patched in version 7.1.2.",
#         "format": "markdown"
#     },
#     "remediation": {
#         "content": null,
#         "format": "markdown"
#     },
#     "cvss2Summary": {
#         "score": 0.0,
#         "severity": "critical",
#         "vectorString": ""
#     },
#     "cvss3Summary": {
#         "score": 7.2,
#         "severity": "critical",
#         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:H/UI:N/S:U/C:H/I:H/A:H"
#     },
#     "exploits": [
#         {
#             "name": "http://packetstormsecurity.com/files/171789/Goanywhere-Encryption-Helper-7.1.1-Remote-Code-Execution.html",
#             "url": "http://packetstormsecurity.com/files/171789/Goanywhere-Encryption-Helper-7.1.1-Remote-Code-Execution.html"
#         }
#     ],
#     "references": [
#         {
#             "name": "https://my.goanywhere.com/webclient/ViewSecurityAdvisories.xhtml#zerodayfeb1",
#             "url": "https://my.goanywhere.com/webclient/ViewSecurityAdvisories.xhtml#zerodayfeb1"
#         },
#         {
#             "name": "https://infosec.exchange/@briankrebs/109795710941843934",
#             "url": "https://infosec.exchange/@briankrebs/109795710941843934"
#         },
#         {
#             "name": "https://www.rapid7.com/blog/post/2023/02/03/exploitation-of-goanywhere-mft-zero-day-vulnerability/",
#             "url": "https://www.rapid7.com/blog/post/2023/02/03/exploitation-of-goanywhere-mft-zero-day-vulnerability/"
#         },
#         {
#             "name": "https://attackerkb.com/topics/mg883Nbeva/cve-2023-0669/rapid7-analysis",
#             "url": "https://attackerkb.com/topics/mg883Nbeva/cve-2023-0669/rapid7-analysis"
#         },
#         {
#             "name": "https://github.com/rapid7/metasploit-framework/pull/17607",
#             "url": "https://github.com/rapid7/metasploit-framework/pull/17607"
#         },
#         {
#             "name": "https://duo.com/decipher/fortra-patches-actively-exploited-zero-day-in-goanywhere-mft",
#             "url": "https://duo.com/decipher/fortra-patches-actively-exploited-zero-day-in-goanywhere-mft"
#         },
#         {
#             "name": "https://frycos.github.io/vulns4free/2023/02/06/goanywhere-forgotten.html",
#             "url": "https://frycos.github.io/vulns4free/2023/02/06/goanywhere-forgotten.html"
#         },
#         {
#             "name": "http://packetstormsecurity.com/files/171789/Goanywhere-Encryption-Helper-7.1.1-Remote-Code-Execution.html",
#             "url": "http://packetstormsecurity.com/files/171789/Goanywhere-Encryption-Helper-7.1.1-Remote-Code-Execution.html"
#         }
#     ]
# }

# %% [markdown]
# #### For trouble shooting, will return header information with the expected output

# %%
import requests
import json

# Graph API base URL
graph_api_base_url = "https://graph.microsoft.com/beta/security/threatIntelligence/hosts/062fe.com/reputation"

# Create headers with Authorization token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Send GET request to Graph API endpoint
response = requests.get(graph_api_base_url, headers=headers)

# Check for HTTP errors
try:
    response.raise_for_status()
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
else:
    # Print response headers
    print("Response Headers:")
    print("-----------------")
    for header, value in response.headers.items():
        print(f"{header}: {value}")
    print()

    # Print response content as JSON
    print("Response Content:")
    print("-----------------")
    print(json.dumps(json.loads(response.content), indent=4))
# Out:
# Response Headers:
# -----------------
# Cache-Control: no-store, must-revalidate, no-cache, max-age=0
# Pragma: no-cache
# Transfer-Encoding: chunked
# Content-Type: application/json;odata.metadata=minimal;odata.streaming=true;IEEE754Compatible=false;charset=utf-8
# Content-Encoding: gzip
# Expires: 0
# Strict-Transport-Security: max-age=31536000
# request-id: 87560e26-fa77-468a-8600-504f20dc348b
# client-request-id: 87560e26-fa77-468a-8600-504f20dc348b
# x-ms-ags-diagnostic: {"ServerInfo":{"DataCenter":"North Central US","Slice":"E","Ring":"3","ScaleUnit":"001","RoleInstance":"CH01EPF0000D455"}}
# X-Content-Type-Options: nosniff
# OData-Version: 4.0
# Vary: Origin,Access-Control-Request-Method,Access-Control-Request-Headers, Accept-Encoding
# Date: Fri, 14 Apr 2023 13:17:52 GMT
#
# Response Content:
# -----------------
# {
#     "@odata.context": "https://graph.microsoft.com/beta/$metadata#security/threatIntelligence/hosts('062fe.com')/reputation/$entity",
#     "id": "MDYyZmUuY29t",
#     "score": 100,
#     "classification": "malicious",
#     "rules": [
#         {
#             "name": "MDTI Intel Article",
#             "description": "Threat Insights: DEV-1101 NakedPages adversary-in-the-middle phishing kit",
#             "severity": "high",
#             "relatedDetailsUrl": "https://ti.defender.microsoft.com/article/e0c5c210"
#         },
#         {
#             "name": "Microsoft Blocklist (WatchList)",
#             "description": "This indicator relates to an emerging threat actor DEV-0563",
#             "severity": "high",
#             "relatedDetailsUrl": null
#         },
#         {
#             "name": "Microsoft Blocklist (WatchList)",
#             "description": "Please read the linked article(s) for more information on this threat. [\"https://ti.defender.microsoft.com/article/e0c5c210\"]",
#             "severity": "high",
#             "relatedDetailsUrl": null
#         },
#         {
#             "name": "Name server",
#             "description": "Domain is using a name server that has been associated with suspicious behavior",
#             "severity": "medium",
#             "relatedDetailsUrl": null
#         }
#     ]
# }
